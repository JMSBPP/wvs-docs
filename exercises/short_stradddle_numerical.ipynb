# %% [markdown]
# ##
#
# Consider an asset with a continuous price distribution. Over the lifetime of this asset, $T∗$ the trader takes a random $T-t$
# sample at the current date $t_0$. The trader's forecasted volatility approach is not based on fundamentals; instead, he is running a forecasting tool on the historical price data and comes up with a forecasted volatility figure, which he will use as a proxy for his belief about future volatility.
#
# The following is needed now:
#
# 1. Generate a brownian motion for the price
# 2. Generate a order book as posin process over current $t_0$
# 3. Generate a sample of expiration times.
# 4. Generate a implied volatility value as a forecasted value idffernt tahn the trade one tht is used for all subsequent options ot be priced
# 5. Over the size of expiration times, generate calls and puts over some subset of orders on the order book thius forming an order book of options. Price them using ONLY BS model
